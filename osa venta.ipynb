# %%
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib as ploty

# %%
#Datasets de compra de productos a proveedores 2021-2022
precio_enejun= pd.read_excel("Evolución_precio_enerojunio22.xls")
precio_juldic= pd.read_excel("Evolución_precio_juliodiciembre22.xls")
precio_2021= pd.read_excel("Price_history_2021.xls")
precio_2022= pd.read_excel("Price_history_122022.xls")

# %%
#Datasets de venta de productis al publico 2021-2022
ventas_2021= pd.read_excel("inflacion_osa_2021.xls")
ventas_2022= pd.read_excel("inflacion_osa_2022.xls")

# %%
#Sorting Products Descending By Sales
Sales_info = ventas_2021[["Product Name" , "Sales"]].sort_values(by=['Sales'] , ascending = False)
Sales_info.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Sorting Products Descending By Sales
# ----> 2 Sales_info = ventas_2021[["Product Name" , "Sales"]].sort_values(by=['Sales'] , ascending = False)
#       3 Sales_info.head(10)
#
# File ~/miniconda3/envs/osa/lib/python3.8/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/envs/osa/lib/python3.8/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/osa/lib/python3.8/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Product Name', 'Sales'], dtype='object')] are in the [columns]"

# %%
ventas_2021.head()
# Out:
#                                           Unnamed: 0              Total  \
# 0                                                NaN         enero 2021
# 1                                                NaN  Cantidad producto
# 2                                              Total           22238.75
# 3       [000007] Aceite árnica y romero Piel sana...                NaN
# 4       [000008] Aceite caléndula y almendras Pie...                  2
#
#      Unnamed: 2         Unnamed: 3    Unnamed: 4         Unnamed: 5  \
# 0           NaN       febrero 2021           NaN         marzo 2021
# 1  Precio medio  Cantidad producto  Precio medio  Cantidad producto
# 2      3.241511          26905.815      3.217539          29978.455
# 3           NaN                  1          11.7                NaN
# 4          12.5                NaN           NaN                  1
#
#      Unnamed: 6         Unnamed: 7    Unnamed: 8         Unnamed: 9  ...  \
# 0           NaN         abril 2021           NaN          mayo 2021  ...
# 1  Precio medio  Cantidad producto  Precio medio  Cantidad producto  ...
# 2      3.259158          28332.157      3.391073          25373.829  ...
# 3           NaN                NaN           NaN                NaN  ...
# 4          12.5                NaN           NaN                NaN  ...
#
#          Unnamed: 17   Unnamed: 18        Unnamed: 19   Unnamed: 20  \
# 0    septiembre 2021           NaN       octubre 2021           NaN
# 1  Cantidad producto  Precio medio  Cantidad producto  Precio medio
# 2          25386.211       3.38311          28317.427      3.581475
# 3                NaN           NaN                NaN           NaN
# 4                NaN           NaN                NaN           NaN
#
#          Unnamed: 21   Unnamed: 22        Unnamed: 23   Unnamed: 24  \
# 0     noviembre 2021           NaN     diciembre 2021           NaN
# 1  Cantidad producto  Precio medio  Cantidad producto  Precio medio
# 2          28297.971      3.822941          28992.494      3.974771
# 3                NaN           NaN                NaN           NaN
# 4                NaN           NaN                NaN           NaN
#
#          Unnamed: 25   Unnamed: 26
# 0                NaN           NaN
# 1  Cantidad producto  Precio medio
# 2         309315.499      3.484218
# 3                  1          11.7
# 4                  5          12.5
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Pruebas iniciales DataFrame Ventas
